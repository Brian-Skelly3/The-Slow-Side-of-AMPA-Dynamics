# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Means are useless if there's multiple minima

# %%
data1.sort(axis=0)
dataT1.sort(axis=0)

# %%
print(data1[0,:], data1[-1,:])
print(dataT1[0,:], dataT1[-1,:])
# Out:
# [9.02264398e-01 3.28645962e+02 1.31925633e+00 1.28081380e-03] [9.02266329e-01 3.32805445e+02 1.31925931e+00 1.28232988e-03]
# [ 9.07374576 64.51876521  1.18875606  0.23142562] [ 9.12883735 64.55796333  1.18970194  0.23217086]

# %% [markdown]
# ## X and U params with new K and g
# Unpenalised. Not new anymore

# %%
data5 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq5.npy')
data10 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq10.npy')
data20 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq20.npy')
data50 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq50.npy')
data100 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq100.npy')
data200 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq200.npy')
data300 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq300.npy')
data400 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq400.npy')
data500 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XUnew_alph1_avfreq500.npy')

dataT5 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq5.npy')
dataT10 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq10.npy')
dataT20 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq20.npy')
dataT50 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq50.npy')
dataT100 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq100.npy')
dataT200 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq200.npy')
dataT300 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq300.npy')
dataT400 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq400.npy')
dataT500 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XUnew_alph1_avfreq500.npy')

# %%
# UnTARPed data
#    TauX
# plt.scatter(np.zeros_like(data5[:,0]) + 5, data5[:,0])
# plt.scatter(np.zeros_like(data10[:,0]) + 10, data10[:,0])
# plt.scatter(np.zeros_like(data20[:,0]) + 20, data20[:,0])
# plt.scatter(np.zeros_like(data50[:,0]) + 50, data50[:,0])
# plt.scatter(np.zeros_like(data100[:,0]) + 100, data100[:,0])
# plt.scatter(np.zeros_like(data200[:,0]) + 200, data200[:,0])
# plt.scatter(np.zeros_like(data300[:,0]) + 300, data300[:,0])
# plt.scatter(np.zeros_like(data400[:,0]) + 400, data400[:,0])
# plt.scatter(np.zeros_like(data500[:,0]) + 500, data500[:,0])
# plt.ylim(350,400)

#    TauU
# plt.scatter(np.zeros_like(data5[:,1]) + 5, data5[:,1])
# plt.scatter(np.zeros_like(data10[:,1]) + 10, data10[:,1])
# plt.scatter(np.zeros_like(data20[:,1]) + 20, data20[:,1])
# plt.scatter(np.zeros_like(data50[:,1]) + 50, data50[:,1])
# plt.scatter(np.zeros_like(data100[:,1]) + 100, data100[:,1])
# plt.scatter(np.zeros_like(data200[:,1]) + 200, data200[:,1])
# plt.scatter(np.zeros_like(data300[:,1]) + 300, data300[:,1])
# plt.scatter(np.zeros_like(data400[:,1]) + 400, data400[:,1])
# plt.scatter(np.zeros_like(data500[:,1]) + 500, data500[:,1])
# plt.ylim(0,50)

# TARPed data
#    TauX
# plt.scatter(np.zeros_like(dataT5[:,0]) + 5, dataT5[:,0])
# plt.scatter(np.zeros_like(dataT10[:,0]) + 10, dataT10[:,0])
# plt.scatter(np.zeros_like(dataT20[:,0]) + 20, dataT20[:,0])
# plt.scatter(np.zeros_like(dataT50[:,0]) + 50, dataT50[:,0])
# plt.scatter(np.zeros_like(dataT100[:,0]) + 100, dataT100[:,0])
# plt.scatter(np.zeros_like(dataT200[:,0]) + 200, dataT200[:,0])
# plt.scatter(np.zeros_like(dataT300[:,0]) + 300, dataT300[:,0])
# plt.scatter(np.zeros_like(dataT400[:,0]) + 400, dataT400[:,0])
# plt.scatter(np.zeros_like(dataT500[:,0]) + 500, dataT500[:,0])

#    TauU
# plt.scatter(np.zeros_like(dataT5[:,1]) + 5, dataT5[:,1])
# plt.scatter(np.zeros_like(dataT10[:,1]) + 10, dataT10[:,1])
# plt.scatter(np.zeros_like(dataT20[:,1]) + 20, dataT20[:,1])
# plt.scatter(np.zeros_like(dataT50[:,1]) + 50, dataT50[:,1])
# plt.scatter(np.zeros_like(dataT100[:,1]) + 100, dataT100[:,1])
# plt.scatter(np.zeros_like(dataT200[:,1]) + 200, dataT200[:,1])
# plt.scatter(np.zeros_like(dataT300[:,1]) + 300, dataT300[:,1])
# plt.scatter(np.zeros_like(dataT400[:,1]) + 400, dataT400[:,1])
# plt.scatter(np.zeros_like(dataT500[:,1]) + 500, dataT500[:,1])
# plt.ylim(0,10)

# %%
data20
# Out:
# array([[178.22287918, 363.24087821],
#        [178.222628  , 363.2426256 ],
#        [179.45860106, 231.10598585],
#        [178.22242118, 363.2400095 ],
#        [178.22252884, 363.24118481],
#        [167.18163869, 170.48268371],
#        [178.22302523, 363.24037635],
#        [178.22256315, 363.24048835],
#        [178.22243258, 363.24029465],
#        [178.22241295, 363.23972054],
#        [178.22245503, 363.24006814],
#        [178.22249571, 363.24137636],
#        [178.222507  , 363.24147392],
#        [178.22242919, 363.24015595],
#        [178.22252784, 363.24099446],
#        [178.2224389 , 363.24040858],
#        [178.22258884, 363.24206467],
#        [178.22254665, 363.24221187],
#        [178.22240625, 363.23980856],
#        [180.91812252, 234.84929154],
#        [178.22259824, 363.24039114],
#        [178.22239808, 363.23964434],
#        [178.22252998, 363.24132174],
#        [178.2224031 , 363.23980165],
#        [178.22249704, 363.24139588],
# ...

# %% [markdown]
# ## Mixed frequencies

# %%
# New
# This is with the new penalised parameters for K and g dynamics
# data1 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_penalty_mixedfreq.npy')
data1 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_penalty_mixedfreq_fine.npy')
dataT1 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_penalty_mixedfreq_fine.npy')

# %%
print(np.median(data1, axis=0))
print(np.mean(data1, axis=0))
print(np.median(dataT1, axis=0))
print(np.mean(dataT1, axis=0))
# Out:
# [343.65632185 433.01193232]
# [343.89343256 447.71309721]
# [56.46263779  0.5193005 ]
# [56.51479926  0.54436705]

# %%
plt.figure(figsize=(14,8))
plt.suptitle('Optimised parameter values', fontsize=24)


plt.subplot(2,2,1)
plt.boxplot(data1[:,0])
plt.title('$τ_X$', fontsize=18)
plt.subplot(2,2,2)
plt.boxplot(data1[:,1])
plt.title('$τ_U$', fontsize=18)


plt.subplot(2,2,3)
plt.boxplot(dataT1[:,0])
plt.subplot(2,2,4)
plt.boxplot(dataT1[:,1])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2364f9ef650>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2364f9f4f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2364f9eea50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2364f9f6410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2364f9cdc10>],
#  'means': []}

# %%
# Scatter plot

plt.figure(figsize=(14,8))

plt.subplot(2,2,1)
plt.scatter(np.zeros_like(data1[:,0]) + 5, data1[:,0])
plt.title('$τ_X$', fontsize=18)
plt.subplot(2,2,2)
plt.scatter(np.zeros_like(data1[:,1]) + 5, data1[:,1])
plt.title('$τ_U$', fontsize=18)


plt.subplot(2,2,3)
plt.scatter(np.zeros_like(dataT1[:,0]) + 5, dataT1[:,0])
plt.subplot(2,2,4)
plt.scatter(np.zeros_like(dataT1[:,1]) + 5, dataT1[:,1])

# %% [markdown]
# ## X and U params with old K and g

# %%
# data5 = np.load('opt_params_2alphaTARPed_XU_avfreq5.npy')
# data10 = np.load('opt_params_2alphaTARPed_XU_avfreq10.npy')
# data20 = np.load('opt_params_2alphaTARPed_XU_avfreq20.npy')
# data50 = np.load('opt_params_2alphaTARPed_XU_avfreq50.npy')
# data100 = np.load('opt_params_2alphaTARPed_XU_avfreq100.npy')
# data200 = np.load('opt_params_2alphaTARPed_XU_avfreq200.npy')
# data300 = np.load('opt_params_2alphaTARPed_XU_avfreq300.npy')
# data400 = np.load('opt_params_2alphaTARPed_XU_avfreq400.npy')
# data500 = np.load('opt_params_2alphaTARPed_XU_avfreq500.npy')

data5 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq5.npy')
data10 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq10.npy')
data20 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq20.npy')
data50 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq50.npy')
data100 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq100.npy')
data200 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq200.npy')
data300 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq300.npy')
data400 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq400.npy')
data500 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaunTARPed_XU_alph1_avfreq500.npy')

dataT5 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq5.npy')
dataT10 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq10.npy')
dataT20 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq20.npy')
dataT50 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq50.npy')
dataT100 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq100.npy')
dataT200 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq200.npy')
dataT300 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq300.npy')
dataT400 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq400.npy')
dataT500 = np.load('C:/Users/brian/AMPA-Project/Data/opt_params_2alphaTARPed_XU_alph1_avfreq500.npy')

# %%
means = np.array([np.mean(data5, axis=0), np.mean(data10, axis=0), np.mean(data20, axis=0), np.mean(data50, axis=0), np.mean(data100, axis=0), np.mean(data200, axis=0), np.mean(data300, axis=0), np.mean(data400, axis=0), np.mean(data500, axis=0)])
med = np.array([np.median(data5, axis=0), np.median(data10, axis=0), np.median(data20, axis=0), np.median(data50, axis=0), np.median(data100, axis=0), np.median(data200, axis=0), np.median(data300, axis=0), np.median(data400, axis=0), np.median(data500, axis=0)])

varis = np.array([np.var(data5, axis=0), np.var(data10, axis=0), np.var(data20, axis=0), np.var(data50, axis=0), np.var(data100, axis=0), np.var(data200, axis=0), np.var(data300, axis=0), np.var(data400, axis=0), np.var(data500, axis=0)])
freqs = np.array([5, 10, 20, 50, 100, 200, 300, 400, 500])

print('Means:')
print('tauX = ', means[:,0])
print('tauU = ', means[:,1])
# print('alpha = ', means[:,2])
print('\n')
print('Medians:')
print('tauX = ', med[:,0])
print('tauU = ', med[:,1])
print('\n')
print('standard Deviation:')
print('tauX = ', np.sqrt(varis[:,0]))
print('tauU = ', np.sqrt(varis[:,1]))
# print('alpha = ', np.sqrt(varis[:,2]))
print('\n')
print('Overall Means:')
print('tauX = ', np.mean(means[:,0]))
print('tauU = ', np.mean(means[:,1]))
# print('alpha = ', np.mean(means[:,2]))
print('\n')
print('Overall Medians:')
print('tauX = ', np.median(med[:,0]))
print('tauU = ', np.median(med[:,1]))
# Out:
# Means:
# tauX =  [  1.00661114  83.4565476  177.98555858 206.99925691 193.68252506
#  205.82527207 222.49259874 242.18426202 239.9564861 ]
# tauU =  [236.99506738 134.78749171 348.13124919  89.77553314 109.5416085
#   19.71268782  19.77216072   5.33833416  19.82774614]
#
#
# Medians:
# tauX =  [  1.00658166  79.85189011 178.22251194 228.26131152 194.69179043
#  205.95087022 222.42854342 243.81043142 239.9552754 ]
# tauU =  [237.40661295  14.44175529 363.24038375  84.62255316  19.69250014
#   19.73209504  19.77801985   5.34019796  19.82812999]
#
#
# standard Deviation:
# tauX =  [1.58721393e-04 3.56771340e+01 2.07373020e+00 4.15866056e+01
#  1.95190178e+00 9.48959959e-01 1.61963167e-01 3.63331530e+00
#  2.12785230e-02]
# tauU =  [2.22188787e+00 1.93231752e+02 4.62784054e+01 8.58250833e+00
#  1.49062511e+02 5.38395172e-02 1.46993752e-02 3.22797299e-03
#  3.08785783e-03]
#
#
# Overall Means:
# tauX =  174.8432353560055
# tauU =  109.3202087513583
#
#
# Overall Medians:
# ...

# %%
meansT = np.array([np.mean(dataT5, axis=0), np.mean(dataT10, axis=0), np.mean(dataT20, axis=0), np.mean(dataT50, axis=0), np.mean(dataT100, axis=0), np.mean(dataT200, axis=0), np.mean(dataT300, axis=0), np.mean(dataT400, axis=0), np.mean(dataT500, axis=0)])
medT = np.array([np.median(dataT5, axis=0), np.median(dataT10, axis=0), np.median(dataT20, axis=0), np.median(dataT50, axis=0), np.median(dataT100, axis=0), np.median(dataT200, axis=0), np.median(dataT300, axis=0), np.median(dataT400, axis=0), np.median(dataT500, axis=0)])

varisT = np.array([np.var(dataT5, axis=0), np.var(dataT10, axis=0), np.var(dataT20, axis=0), np.var(dataT50, axis=0), np.var(dataT100, axis=0), np.var(dataT200, axis=0), np.var(dataT300, axis=0), np.var(dataT400, axis=0), np.var(dataT500, axis=0)])
freqsT = np.array([5, 10, 20, 50, 100, 200, 300, 400, 500])

print('Means:')
print('tauX = ', meansT[:,0])
print('tauU = ', meansT[:,1])
# print('alpha = ', meansT[:,2])
print('\n')
print('Medians:')
print('tauX = ', medT[:,0])
print('tauU = ', medT[:,1])
print('\n')
print('standard Deviation:')
print('tauX = ', np.sqrt(varisT[:,0]))
print('tauU = ', np.sqrt(varisT[:,1]))
# print('alpha = ', np.sqrt(varisT[:,2]))
print('\n')
print('Overall Means:')
print('tauX = ', np.mean(meansT[:,0]))
print('tauU = ', np.mean(meansT[:,1]))
# print('alpha = ', np.mean(meansT[:,2]))
print('\n')
print('Overall Medians:')
print('tauX = ', np.median(medT[:,0]))
print('tauU = ', np.median(medT[:,1]))
# Out:
# Means:
# tauX =  [ 1.00610107  1.66267692 28.53717083 44.82845482 49.30164365 51.74660549
#  53.34518839 53.40973047 53.71095727]
# tauU =  [440.82788978 137.75863344   1.06866779  12.02224796   0.7532411
#   10.92395447   9.81714596   7.46564047   0.89835427]
#
#
# Medians:
# tauX =  [ 1.00530907  1.43666441 28.60547855 44.96112775 49.22582558 51.53663216
#  53.32243753 53.33866607 53.64587272]
# tauU =  [499.99206883 109.65398173   0.99400484   1.30320577   0.51666035
#    1.15259589   0.5796838    0.7238443    0.9473364 ]
#
#
# standard Deviation:
# tauX =  [0.00149305 0.34940353 0.3819356  1.09051357 0.17466027 0.65577311
#  0.1237157  0.12514302 0.16989729]
# tauU =  [100.16302074 118.48164116   0.1926511   57.7020238    0.39754155
#   53.58877501  49.74525616  35.83892344   0.12493468]
#
#
# Overall Means:
# tauX =  37.505392103473575
# tauU =  69.05953058144809
#
#
# Overall Medians:
# tauX =  49.225825579791945
# tauU =  0.9940048381123887

# %%
# plt.boxplot((data5[:,0], data10[:,0], data20[:,0], data50[:,0], data100[:,0], data200[:,0], data300[:,0], data400[:,0], data500[:,0]))
plt.boxplot((data5[:,1], data10[:,1], data20[:,1], data50[:,1], data100[:,1], data200[:,1], data300[:,1], data400[:,1], data500[:,1]))

# plt.boxplot((dataT5[:,0], dataT10[:,0], dataT20[:,0], dataT50[:,0], dataT100[:,0], dataT200[:,0], dataT300[:,0], dataT400[:,0], dataT500[:,0]))
# plt.boxplot((dataT5[:,1], dataT10[:,1], dataT20[:,1], dataT50[:,1], dataT100[:,1], dataT200[:,1], dataT300[:,1], dataT400[:,1], dataT500[:,1]))

# plt.ylim(330, 400)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x219f8674c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x219f8675e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x219f8674410>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x219f8676f50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x219f8676ed0>,
# ...
#  'means': []}

# %%
# UnTARPed data
#    TauX
plt.scatter(np.zeros_like(data5[:,0]) + 5, data5[:,0])
plt.scatter(np.zeros_like(data10[:,0]) + 10, data10[:,0])
plt.scatter(np.zeros_like(data20[:,0]) + 20, data20[:,0])
plt.scatter(np.zeros_like(data50[:,0]) + 50, data50[:,0])
plt.scatter(np.zeros_like(data100[:,0]) + 100, data100[:,0])
plt.scatter(np.zeros_like(data200[:,0]) + 200, data200[:,0])
plt.scatter(np.zeros_like(data300[:,0]) + 300, data300[:,0])
plt.scatter(np.zeros_like(data400[:,0]) + 400, data400[:,0])
plt.scatter(np.zeros_like(data500[:,0]) + 500, data500[:,0])

# #    TauU
# plt.scatter(np.zeros_like(data5[:,1]) + 5, data5[:,1])
# plt.scatter(np.zeros_like(data10[:,1]) + 10, data10[:,1])
# plt.scatter(np.zeros_like(data20[:,1]) + 20, data20[:,1])
# plt.scatter(np.zeros_like(data50[:,1]) + 50, data50[:,1])
# plt.scatter(np.zeros_like(data100[:,1]) + 100, data100[:,1])
# plt.scatter(np.zeros_like(data200[:,1]) + 200, data200[:,1])
# plt.scatter(np.zeros_like(data300[:,1]) + 300, data300[:,1])
# plt.scatter(np.zeros_like(data400[:,1]) + 400, data400[:,1])
# plt.scatter(np.zeros_like(data500[:,1]) + 500, data500[:,1])
# plt.ylim(0,50)

# TARPed data
#    TauX
# plt.scatter(np.zeros_like(dataT5[:,0]) + 5, dataT5[:,0])
# plt.scatter(np.zeros_like(dataT10[:,0]) + 10, dataT10[:,0])
# plt.scatter(np.zeros_like(dataT20[:,0]) + 20, dataT20[:,0])
# plt.scatter(np.zeros_like(dataT50[:,0]) + 50, dataT50[:,0])
# plt.scatter(np.zeros_like(dataT100[:,0]) + 100, dataT100[:,0])
# plt.scatter(np.zeros_like(dataT200[:,0]) + 200, dataT200[:,0])
# plt.scatter(np.zeros_like(dataT300[:,0]) + 300, dataT300[:,0])
# plt.scatter(np.zeros_like(dataT400[:,0]) + 400, dataT400[:,0])
# plt.scatter(np.zeros_like(dataT500[:,0]) + 500, dataT500[:,0])

#    TauU
# plt.scatter(np.zeros_like(dataT5[:,1]) + 5, dataT5[:,1])
# plt.scatter(np.zeros_like(dataT10[:,1]) + 10, dataT10[:,1])
# plt.scatter(np.zeros_like(dataT20[:,1]) + 20, dataT20[:,1])
# plt.scatter(np.zeros_like(dataT50[:,1]) + 50, dataT50[:,1])
# plt.scatter(np.zeros_like(dataT100[:,1]) + 100, dataT100[:,1])
# plt.scatter(np.zeros_like(dataT200[:,1]) + 200, dataT200[:,1])
# plt.scatter(np.zeros_like(dataT300[:,1]) + 300, dataT300[:,1])
# plt.scatter(np.zeros_like(dataT400[:,1]) + 400, dataT400[:,1])
# plt.scatter(np.zeros_like(dataT500[:,1]) + 500, dataT500[:,1])
# plt.ylim(0,10)

# %%
data1
# Out:
# array([[1.07655085e+00, 8.67497940e+02, 8.05628942e-01, 1.22022904e-03],
#        [1.07582608e+00, 8.21032892e+02, 8.05088066e-01, 1.22339197e-03],
#        [1.07581571e+00, 8.29730782e+02, 8.05079001e-01, 1.22375149e-03],
#        [1.07614906e+00, 9.21906516e+02, 8.05321617e-01, 1.21918999e-03],
#        [1.07581218e+00, 7.79189019e+02, 8.05151009e-01, 1.22510848e-03],
#        [1.07608589e+00, 7.91151301e+02, 8.05315397e-01, 1.22517052e-03],
#        [1.07647279e+00, 8.42740149e+02, 8.05592328e-01, 1.22256583e-03],
#        [1.07518621e+00, 7.81044187e+02, 8.04616188e-01, 1.22597225e-03],
#        [1.07564595e+00, 8.82797304e+02, 8.05019470e-01, 1.21903783e-03],
#        [1.07521160e+00, 8.64025858e+02, 8.04574527e-01, 1.22062906e-03],
#        [1.07597778e+00, 7.62669114e+02, 8.05227728e-01, 1.22608603e-03],
#        [1.07574688e+00, 8.47614092e+02, 8.05005801e-01, 1.22231965e-03],
#        [1.07570979e+00, 8.05006091e+02, 8.05049120e-01, 1.22445006e-03],
# ...

# %%
# UnTARPed data
# plt.scatter(np.zeros_like(data1[:,0]) + 1, data1[:,0])
# plt.scatter(np.zeros_like(data1[:,1]) + 1, data1[:,1])
# plt.scatter(np.zeros_like(data1[:,2]) + 1, data1[:,2])
# plt.scatter(np.zeros_like(data1[:,3]) + 1, data1[:,3])

# # TARPed data
# plt.scatter(np.zeros_like(dataT1[:,0]) + 1, dataT1[:,0])
# plt.scatter(np.zeros_like(dataT1[:,1]) + 2, dataT1[:,1])
# plt.scatter(np.zeros_like(dataT1[:,2]) + 1, dataT1[:,2])
plt.scatter(np.zeros_like(dataT1[:,3]) + 1, dataT1[:,3])

# %%
# plt.plot(freqs, means[:,0], label='UnTARPed tauX')
# plt.plot(freqsT, meansT[:,0], label='TARPed tauX')

# plt.plot(freqs, means[:,1], label='UnTARPed tauU')
plt.plot(freqsT, meansT[:,1], label='TARPed tauU')
plt.legend()

# %%
plt.boxplot(data10)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23f450e9b90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23f450ea750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23f450e8810>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x23f45067fd0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x23f450eaad0>,
# ...
#  'means': []}

# %%
data20
# Out:
# array([[330.07094601, 180.90339103],
#        [332.52994701, 181.7948131 ],
#        [333.484507  , 185.13394632],
#        [330.07086635, 180.90305352],
#        [375.84453755, 195.45496143],
#        [330.07111849, 180.90418552],
#        [330.07119077, 180.90450715],
#        [330.07090519, 180.90321957],
#        [333.48449617, 185.13396572],
#        [333.48446188, 185.13387125],
#        [333.48453554, 185.13408563],
#        [333.48455323, 185.13406547],
#        [375.84461011, 195.45527268],
#        [330.07086542, 180.90305173],
#        [330.07106635, 180.90377232],
#        [338.27137061, 193.71306905],
#        [330.0711168 , 180.90409371],
#        [330.06976541, 180.89810467],
#        [333.48455831, 185.13406525],
#        [333.48452572, 185.13407362],
#        [333.48464307, 185.13400738],
#        [333.48452696, 185.13404796],
#        [333.48453319, 185.13407624],
#        [330.07120529, 180.90457413],
#        [398.2284964 , 193.60676377],
# ...

# %%
# Scatter plots to show if it is actually just variable and smooth, or if there are two+ distinct clusters

#TauX
# plt.plot(data5[:,0], linestyle='none', marker='.', label='5 Hz')
# plt.plot(data10[:,0], linestyle='none', marker='.', label='10 Hz')
# plt.plot(data20[:,0], linestyle='none', marker='.', label='20 Hz')
# plt.plot(data50[:,0], linestyle='none', marker='.', label='50 Hz')
# plt.plot(data100[:,0], linestyle='none', marker='.', label='100 Hz')
# plt.plot(data200[:,0], linestyle='none', marker='.', label='200 Hz')
# plt.plot(data300[:,0], linestyle='none', marker='.', label='300 Hz')
# plt.plot(data400[:,0], linestyle='none', marker='.', label='400 Hz')
plt.plot(data500[:,0], linestyle='none', marker='.', label='500 Hz')

# plt.plot(dataT5[:,0], linestyle='none', marker='.', label='5 Hz')
# plt.plot(dataT10[:,0], linestyle='none', marker='.', label='10 Hz')
# plt.plot(dataT20[:,0], linestyle='none', marker='.', label='20 Hz')
# plt.plot(dataT50[:,0], linestyle='none', marker='.', label='50 Hz')
# plt.plot(dataT100[:,0], linestyle='none', marker='.', label='100 Hz')
# plt.plot(dataT200[:,0], linestyle='none', marker='.', label='200 Hz')
# plt.plot(dataT300[:,0], linestyle='none', marker='.', label='300 Hz')
# plt.plot(dataT400[:,0], linestyle='none', marker='.', label='400 Hz')
# plt.plot(dataT500[:,0], linestyle='none', marker='.', label='500 Hz')


#TauU
# plt.plot(data5[:,1], linestyle='none', marker='.', label='5 Hz')
# plt.plot(data10[:,1], linestyle='none', marker='.', label='10 Hz')
# plt.plot(data20[:,1], linestyle='none', marker='.', label='20 Hz')
# plt.plot(data50[:,1], linestyle='none', marker='.', label='50 Hz')
# plt.plot(data100[:,1], linestyle='none', marker='.', label='100 Hz')
# plt.plot(data200[:,1], linestyle='none', marker='.', label='200 Hz')
# plt.plot(data300[:,1], linestyle='none', marker='.', label='300 Hz')
# plt.plot(data400[:,1], linestyle='none', marker='.', label='400 Hz')
# plt.plot(data500[:,1], linestyle='none', marker='.', label='500 Hz')

# plt.plot(dataT5[:,1], linestyle='none', marker='.', label='5 Hz')
# plt.plot(dataT10[:,1], linestyle='none', marker='.', label='10 Hz')
# plt.plot(dataT20[:,1], linestyle='none', marker='.', label='20 Hz')
# plt.plot(dataT50[:,1], linestyle='none', marker='.', label='50 Hz')
# plt.plot(dataT100[:,1], linestyle='none', marker='.', label='100 Hz')
# plt.plot(dataT200[:,1], linestyle='none', marker='.', label='200 Hz')
# plt.plot(dataT300[:,1], linestyle='none', marker='.', label='300 Hz')
# plt.plot(dataT400[:,1], linestyle='none', marker='.', label='400 Hz')
# plt.plot(dataT500[:,1], linestyle='none', marker='.', label='500 Hz')

# %% [markdown]
# ## 2 neurons to find eta

# %%
data1 = np.load(f'C:/Users/brian/AMPA-Project/Data/2neur_04_05eta.npz', allow_pickle=True)

# %%
data1.files
# Out:
# ['t', 'V', 'spiketimes']

# %%
plt.plot(data1['V'][:,0,:])

# %%
data1['V'][:,0,:]
# Out:
# array([[-74.3764215 , -60.01487672],
#        [-74.37581209, -60.01472635],
#        [-74.37520269, -60.01457598],
#        ...,
#        [-49.98104721, -54.00094454],
#        [-49.98104684, -54.00094446],
#        [-49.98104647, -54.00094438]])

# %%
data1 = np.load(f'C:/Users/brian/AMPA-Project/Data/mixed_freq_all_TARPed.npy', allow_pickle=True)

# %%
(range(len(data1[:,0])))
# Out:
# range(0, 10)

# %%
plt.scatter((range(len(data1[:,0]))),data1[:,5])

# %% [markdown]
# ## After setting U_0= 0.4, and 0.85

# %%
data1 = np.load(f'C:/Users/brian/AMPA-Project/Data/opt_params_penalty_unTARPed_Kg_alph1_U0_avfreq1.npy', allow_pickle=True)
dataT1 = np.load(f'C:/Users/brian/AMPA-Project/Data/opt_params_penalty_TARPed_Kg_alph1_U0_avfreq1.npy', allow_pickle=True)

# %%
for i in data1:
	print(i)
# Out:
# [9.28782418e-01 4.04144852e+02 1.53943532e+00 1.51900107e-03]
# [9.28782601e-01 4.02203016e+02 1.53943505e+00 1.51948620e-03]
# [9.28782223e-01 4.03993702e+02 1.53943520e+00 1.51905662e-03]
# [9.28782144e-01 4.03641595e+02 1.53943528e+00 1.51900631e-03]
# [9.28780749e-01 4.04882944e+02 1.53943666e+00 1.51834567e-03]
# [9.28781363e-01 4.04538992e+02 1.53943618e+00 1.51875749e-03]
# [9.28785115e-01 3.99667974e+02 1.53943245e+00 1.52017409e-03]
# [9.28780059e-01 4.05637280e+02 1.53943751e+00 1.51837626e-03]
# [9.28782241e-01 4.03095143e+02 1.53943533e+00 1.51949781e-03]
# [9.28783756e-01 4.01230072e+02 1.53943365e+00 1.51968970e-03]
# [9.28782927e-01 4.02385198e+02 1.53943458e+00 1.51955756e-03]
# [9.28783620e-01 4.01895055e+02 1.53943361e+00 1.51955829e-03]
# [9.28783865e-01 4.01488260e+02 1.53943349e+00 1.51976150e-03]
# [9.28782291e-01 4.03063747e+02 1.53943523e+00 1.51907691e-03]
# [9.28783414e-01 4.02368485e+02 1.53943432e+00 1.51951885e-03]
# ...

# %%
plt.figure(figsize=(16,8), constrained_layout=True)
plt.suptitle('Optimised parameter values', fontsize=24)


plt.subplot(2,4,1)
plt.boxplot(data1[:,0])
plt.title('$τ_K$', fontsize=18)
plt.ylabel('UnTARPed', fontsize=16)
plt.subplot(2,4,2)
plt.boxplot(data1[:,1])
plt.title('$τ_g$', fontsize=18)
plt.subplot(2,4,3)
plt.boxplot(data1[:,2])
plt.title('$A_1$', fontsize=18)
plt.subplot(2,4,4)
plt.boxplot(data1[:,3])
plt.title('$A_2$', fontsize=18)


plt.subplot(2,4,5)
plt.boxplot(dataT1[:,0])
plt.ylabel('TARPed', fontsize=16)
plt.subplot(2,4,6)
plt.boxplot(dataT1[:,1])
plt.subplot(2,4,7)
plt.boxplot(dataT1[:,2])
plt.subplot(2,4,8)
plt.boxplot(dataT1[:,3])



# plt.savefig('Optimised_Parameters_Kg_rescaled.png')

# %%
print(np.median(data1, axis=0))
print(np.median(dataT1, axis=0))
# Out:
# [9.28782606e-01 4.02802597e+02 1.53943493e+00 1.51940434e-03]
# [ 9.02833091 64.51534201  1.23175149  0.23848164]

# %%
print(np.median(data1[:,0]), "[", data1[:,0].min(), ",", data1[:,0].max(),"]")
print(np.median(data1[:,1]), "[", data1[:,1].min(), ",", data1[:,1].max(),"]")
print(np.median(data1[:,2]), "[", data1[:,2].min(), ",", data1[:,2].max(),"]")
print(np.median(data1[:,3]), "[", data1[:,3].min(), ",", data1[:,3].max(),"]")
# Out:
# 0.9287826063383262 [ 0.9287800588049748 , 0.9287851147756356 ]
# 402.8025966605483 [ 399.66797403448396 , 405.6372802205655 ]
# 1.539434926516467 [ 1.5394324459181732 , 1.5394375129403777 ]
# 0.0015194043388095935 [ 0.0015183456736238554 , 0.0015201740921604312 ]

# %%
print(np.median(dataT1[:,0]), "[", dataT1[:,0].min(), ",", dataT1[:,0].max(),"]")
print(np.median(dataT1[:,1]), "[", dataT1[:,1].min(), ",", dataT1[:,1].max(),"]")
print(np.median(dataT1[:,2]), "[", dataT1[:,2].min(), ",", dataT1[:,2].max(),"]")
print(np.median(dataT1[:,3]), "[", dataT1[:,3].min(), ",", dataT1[:,3].max(),"]")
# Out:
# 9.028330914931471 [ 9.027072761259472 , 9.030874127157789 ]
# 64.51534201144571 [ 64.51415067517317 , 64.51691203258494 ]
# 1.2317514940480327 [ 1.231700857636314 , 1.231779987696551 ]
# 0.23848164384896048 [ 0.23845943365274655 , 0.2385093653483985 ]

# %%
data1 = np.load(f'C:/Users/brian/AMPA-Project/Data/Opt_params_unTARPed_XU_U0_mixedfreq.npy', allow_pickle=True)
dataT1 = np.load(f'C:/Users/brian/AMPA-Project/Data/Opt_params_TARPed_XU_U0_mixedfreq.npy', allow_pickle=True)

# %%
print(np.median(data1, axis=0))
print(np.median(dataT1, axis=0))
# Out:
# [465.85577069 263.51486231]
# [57.6343633   0.54811632]

# %%
plt.figure(figsize=(16,8), constrained_layout=True)
plt.suptitle('Optimised parameter values', fontsize=24)


plt.subplot(2,2,1)
plt.boxplot(data1[:,0])
plt.title('$τ_X$', fontsize=18)
plt.ylabel('UnTARPed', fontsize=16)
plt.subplot(2,2,2)
plt.boxplot(data1[:,1])
plt.title('$τ_U$', fontsize=18)



plt.subplot(2,2,3)
plt.boxplot(dataT1[:,0])
plt.ylabel('TARPed', fontsize=16)
plt.subplot(2,2,4)
plt.boxplot(dataT1[:,1])




# plt.savefig('Optimised_Parameters_XU_rescaled.png')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2652a930b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2652a932110>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2652a9300d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2652a933610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2652c2ee2d0>],
#  'means': []}

# %% [markdown]
# ## Single neuron stimulations

# %%
data5 = np.load(f'C:/Users/brian/AMPA-Project/Data/1Neur_5Hz_2600ms_unTARPed_interpolate.npz', allow_pickle=True)
data5T = np.load(f'C:/Users/brian/AMPA-Project/Data/1Neur_5Hz_2600ms_TARPed_interpolate.npz', allow_pickle=True)
data10 = np.load(f'C:/Users/brian/AMPA-Project/Data/1Neur_10Hz_2600ms_unTARPed_interpolate.npz', allow_pickle=True)
data10T = np.load(f'C:/Users/brian/AMPA-Project/Data/1Neur_10Hz_2600ms_TARPed_interpolate.npz', allow_pickle=True)
data20 = np.load(f'C:/Users/brian/AMPA-Project/Data/1Neur_20Hz_2600ms_unTARPed_interpolate.npz', allow_pickle=True)
data20T = np.load(f'C:/Users/brian/AMPA-Project/Data/1Neur_20Hz_2600ms_TARPed_interpolate.npz', allow_pickle=True)

# %%
plt.figure(figsize=(12,15))
plt.subplot(3,1,1)
plt.title('5 Hz', fontsize=26)
plt.plot(data5['t'], data5['V'], label='5 Hz, UnTARPed', color='purple')
plt.plot(data5T['t'], data5T['V'], label='5 Hz, TARPed', color='orange')
plt.ylim(-55,55)
plt.legend(loc='upper right', fontsize=18)
plt.ylabel('Membrane potential (mV)', fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(3,1,2)
plt.title('10 Hz', fontsize=26)
plt.plot(data10['t'], data10['V'], label='10 Hz, UnTARPed', color='purple')
plt.plot(data10T['t'], data10T['V'], label='10 Hz, TARPed', color='orange')
plt.ylim(-55,55)
plt.ylabel('Membrane potential (mV)', fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(3,1,3)
plt.title('20 Hz', fontsize=26)
plt.plot(data20['t'], data20['V'], label='20 Hz, UnTARPed', color='purple')
plt.plot(data20T['t'], data20T['V'], label='20 Hz, TARPed', color='orange')
plt.ylim(-55,55)
plt.ylabel('Membrane potential (mV)', fontsize=24)
plt.xlabel('Time (ms)', fontsize=24	)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.tight_layout()
# plt.savefig('1Neur_PoissonNoise.pdf')

# %%
plt.plot(data5['t'], data5['V'], label='5 Hz, UnTARPed', color='purple')
plt.plot(data5T['t'], data5T['V'], label='5 Hz, TARPed', color='orange')
plt.ylim(-52, -49)
plt.xlim(-5, 50)
# Out:
# (-5.0, 50.0)

# %% [markdown]
# ## Optimised parameters where U_0 can vary

# %%
# New
data1 = np.load('C:/Users/brian/AMPA-Project/Data/Opt_params_unTARPed_XU_U0var_mixedfreq.npy')
dataT1 = np.load('C:/Users/brian/AMPA-Project/Data/Opt_params_TARPed_XU_U0var_mixedfreq.npy')

# %%
data1
# Out:
# array([[410.36453242,   0.50579315,   0.66677225],
#        [419.09563127,   0.70149214,   0.64476584],
#        [428.18115058,   0.66997718,   0.62895259],
#        [424.54943035,   0.64912546,   0.60853591],
#        [425.68042581,   0.68215195,   0.63360539],
#        [424.70083562,   0.67459949,   0.61088484],
#        [424.7008387 ,   0.67459949,   0.61088482],
#        [421.66049694,   0.68273034,   0.62247361],
#        [420.77596899,   0.68249269,   0.62448207],
#        [431.12374523,   0.62647211,   0.62209567],
#        [424.85179872,   0.5058749 ,   0.64700557],
#        [428.66809699,   0.51328618,   0.66251724],
#        [422.47932218,   0.6827322 ,   0.62190202],
#        [424.17214312,   0.68658994,   0.64118962],
#        [429.02910054,   0.64879415,   0.62315553],
#        [430.2998372 ,   0.66423111,   0.6335992 ],
#        [432.05010679,   0.65938659,   0.63147399],
#        [432.23190586,   0.65450007,   0.62991542],
# ...

# %%
print(np.median(data1, axis=0))
print(np.mean(data1, axis=0))
print(np.median(dataT1, axis=0))
print(np.mean(dataT1, axis=0))
# Out:
# [426.05575527   0.66710861   0.62727836]
# [425.71541497   0.65259123   0.62975642]
# [58.2495233   0.56018434  0.93773379]
# [58.46733578  0.55851461  0.93680456]

# %%
print(np.median(data1[:,0]), "[", data1[:,0].min(), ",", data1[:,0].max(),"]")
print(np.median(data1[:,1]), "[", data1[:,1].min(), ",", data1[:,1].max(),"]")
print(np.median(data1[:,2]), "[", data1[:,2].min(), ",", data1[:,2].max(),"]")
# Out:
# 426.0557552675032 [ 410.36453241516494 , 434.1188398980945 ]
# 0.6671086105724129 [ 0.5057931477611817 , 0.7014921409642341 ]
# 0.6272783612519164 [ 0.6085359087658867 , 0.6667722488823837 ]

# %%
print(np.median(dataT1[:,0]), "[", dataT1[:,0].min(), ",", dataT1[:,0].max(),"]")
print(np.median(dataT1[:,1]), "[", dataT1[:,1].min(), ",", dataT1[:,1].max(),"]")
print(np.median(dataT1[:,2]), "[", dataT1[:,2].min(), ",", dataT1[:,2].max(),"]")
# Out:
# 58.24952329715077 [ 57.957679341926905 , 59.60460627525231 ]
# 0.560184338771549 [ 0.5004011902075547 , 0.5868473010796151 ]
# 0.9377337949271534 [ 0.9278815107085819 , 0.9459594277383176 ]

# %%
print(data1[0,:], data1[-1,:])
print(dataT1[0,:], dataT1[-1,:])
# Out:
# [410.36453242   0.50579315   0.60853591] [434.1188399    0.70149214   0.66677225]
# [57.95767934  0.50040119  0.92788151] [59.60460628  0.5868473   0.94595943]

# %%
plt.figure(figsize=(16,8), constrained_layout=True)
plt.suptitle('Optimised parameter values', fontsize=24)


plt.subplot(2,3,1)
plt.boxplot(data1[:,0])
plt.title('$τ_X$', fontsize=18)
plt.ylabel('UnTARPed', fontsize=16)
plt.subplot(2,3,2)
plt.boxplot(data1[:,1])
plt.title('$τ_U$', fontsize=18)
plt.subplot(2,3,3)
plt.boxplot(data1[:,2])
plt.title('$U_0$', fontsize=18)


plt.subplot(2,3,4)
plt.boxplot(dataT1[:,0])
plt.ylabel('TARPed', fontsize=16)
plt.subplot(2,3,5)
plt.boxplot(dataT1[:,1])
plt.subplot(2,3,6)
plt.boxplot(dataT1[:,2])



# plt.savefig('Optimised_Parameters_Kg.png')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x249f7dd31d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x249f7de8250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x249f7dd2850>],
#  'medians': [<matplotlib.lines.Line2D at 0x249f7de9290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x249f7dc2bd0>],
#  'means': []}
